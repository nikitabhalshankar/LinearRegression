# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
bias=100
X,y,coef=make_regression(n_features=1,noise=10,bias=bias,random_state=42,coef=True)

# %%
X.shape,y.shape
# Out:
# ((100, 1), (100,))

# %%
plt.scatter(X,y,coef)

# %%
coef,bias    #i have m and c from sklearn
# Out:
# (array(41.74110031), 100)

# %%
y_gen=X*coef+bias            #equation of line

# %%
plt.scatter(X,y)
plt.plot(X,y_gen)

# %%
#lets plot a line using linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X,y)  #work during traning figuring out m(coefient ) & c(intercept)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_,model.intercept_
# Out:
# (array([44.43716999]), 101.16511532052698)

# %%
plt.scatter(X,y)
plt.plot(X,y_gen,label="previous")
plt.plot(X,model.predict(X),label="LR")
plt.legend()

# %%
class LinearRegCustom:
     #constructor
        
    def __init__(self,lr=0.1):
        self.lr=lr
        
    #traing function i.e fit
    def fit(self,X,y):
        self._X=X         #mock behavior like private
        self._y=y.reshape(-1,1)          #do calculatio else it will give upu error due to numpy shaoe 
        
        
        #need to figure out value of coef and intercept
        #step1: pick these valueat random
        
        self.coef_=np.random.random()
        self.intercept_=np.random.random()
        
        
        #gradient desent
        
        errors=[]
        
        #lets say we do this 30 times
        
        
        for i in range(50):
            self.gradient_decend()
            errors.append(self.error())
            
        return errors
    
    
    
    
    def gradient_decend(self):
        #change in coed and intercept
        
        d_coef,d_intercept=self.gradient()
        self.coef_=d_coef+self.lr
        self.intercept_=d_intercept*self.lr
        
        
        
    def gradient(self):
        yh=self.predict(self._X)    #from predict funtion
        
        d_coef=((yh-self._y)*self._X).mean()
        d_intercept=(yh-self._y).mean()
        
        return d_coef,d_intercept
    
    def predict(self,X):
        return X*self.coef_+self.intercept
